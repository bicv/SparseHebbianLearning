# %% [markdown]
# # Sparse Hebbian Learning : reproducing SparseNet
#
# In this notebook, we test the convergence of SparseNet as a function of different learning parameters. This shows the relative robusteness of this method according to the coding parameters, but also the importance of homeostasis to obtain an efficient set of filters.
#
# See also :
# * http://blog.invibe.net/posts/2015-05-05-reproducing-olshausens-classical-sparsenet.html for a description of how SparseNet is implemented in the scikit-learn package
# * http://blog.invibe.net/posts/2015-05-06-reproducing-olshausens-classical-sparsenet-part-2.html for a descrtiption of how we managed to implement the homeostasis

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(precision=2, suppress=True)

# %%
from shl_scripts import SHL
DEBUG_DOWNSCALE, verbose = 10, 100
DEBUG_DOWNSCALE, verbose = 10, 0
DEBUG_DOWNSCALE, verbose = 1, 0
N_scan = 7

# %% [markdown]
# ## With diferent learning rates but without homeostasis
#
# Here,we only ensure the norm ofthe filters is constant.

# %%
shl = SHL()
for eta in np.logspace(-1, 1, N_scan, base=10)*shl.eta:
    shl = SHL(DEBUG_DOWNSCALE=DEBUG_DOWNSCALE, eta_homeo=0,
              eta=eta, verbose=verbose)
    dico = shl.learn_dico()
    _ = shl.show_dico(dico)

    fig, ax = shl.show_dico(dico, title='homeo - eta={}'.format(eta))
    fig.show()
    fig, ax = shl.plot_variance(dico)
    fig.show()
    fig, ax = shl.plot_variance_histogram(dico)
    fig.show()

# %% [markdown]
# ## Homeostasis à-la-SparseNet

# %%
shl = SHL()
for eta_homeo in np.logspace(-1, 1, N_scan, base=10)*shl.eta_homeo:
    print('eta_homeo=', eta_homeo)
    shl = SHL(DEBUG_DOWNSCALE=DEBUG_DOWNSCALE, 
              eta_homeo=eta_homeo, verbose=verbose)
    dico = shl.learn_dico()

    fig, ax = shl.show_dico(dico, title='homeo - eta_homeo={}'.format(eta_homeo))
    fig.show()
    fig, ax = shl.plot_variance(dico)
    fig.show()
    fig, ax = shl.plot_variance_histogram(dico)
    fig.show()
# Out:
# eta_homeo= 0.005
# eta_homeo= 0.0107721734502
# eta_homeo= 0.0232079441681
# eta_homeo= 0.05
# eta_homeo= 0.107721734502
# eta_homeo= 0.232079441681
# eta_homeo= 0.5

# %%
shl = SHL()
for alpha_homeo in np.logspace(-1, 1, N_scan, base=10)*shl.alpha_homeo:
    print('alpha_homeo=', alpha_homeo)
    shl = SHL(DEBUG_DOWNSCALE=DEBUG_DOWNSCALE, 
              learning_algorithm='omp', alpha_homeo=alpha_homeo, verbose=verbose)
    dico = shl.learn_dico()
    _ = shl.show_dico(dico)

    fig, ax = shl.show_dico(dico, title='homeo - alpha_homeo={}'.format(alpha_homeo))
    fig.show()
    fig, ax = shl.plot_variance(dico)
    fig.show()
    fig, ax = shl.plot_variance_histogram(dico)
    fig.show()
# Out:
# alpha_homeo= 0.02
# alpha_homeo= 0.0430886938006
# alpha_homeo= 0.0928317766723
# alpha_homeo= 0.2
# alpha_homeo= 0.430886938006
# alpha_homeo= 0.928317766723
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d0bc165718d1> in <module>()
#      11     fig, ax = shl.plot_variance(dico)
#      12     fig.show()
# ---> 13     fig, ax = shl.plot_variance_histogram(dico)
#      14     fig.show()
#
# /Users/lolo/pool/science/BICV/SHL_scripts/shl_scripts/shl_scripts.py in plot_variance_histogram(self, dico, name_database, fname)
#     220         ax = fig.add_subplot(111)
#     221         with sns.axes_style("white"):
# --> 222             ax = sns.distplot(df['Variance'], kde=False)#, fit=gamma,  fit_kws={'clip':(0., 5.)})
#     223         ax.set_title('distribution of the mean variance of coefficients')
#     224         ax.set_ylabel('pdf')
#
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     207     if hist:
#     208         if bins is None:
# --> 209             bins = min(_freedman_diaconis_bins(a), 50)
#     210         hist_kws.setdefault("alpha", 0.4)
#     211         hist_kws.setdefault("normed", norm_hist)
#
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      33         return int(np.sqrt(a.size))
#      34     else:
# ---> 35         return int(np.ceil((a.max() - a.min()) / h))
#      36
#      37
#
# ValueError: cannot convert float NaN to integer

# %%
shl = SHL()
for alpha_homeo in np.logspace(-1, 1, N_scan, base=10)*shl.alpha_homeo:
    print('alpha_homeo=', alpha_homeo)
    shl = SHL(DEBUG_DOWNSCALE=DEBUG_DOWNSCALE, 
              learning_algorithm='omp', alpha_homeo=alpha_homeo, verbose=verbose)
    dico = shl.learn_dico()
    _ = shl.show_dico(dico)

    fig, ax = shl.show_dico(dico, title='homeo - alpha_homeo={}'.format(alpha_homeo))
    fig.show()
    fig, ax = shl.plot_variance(dico)
    fig.show()
    fig, ax = shl.plot_variance_histogram(dico)
    fig.show()

# %% [markdown]
# ## Version used

# %%
import version_information
# %version_information numpy, shl_scripts
